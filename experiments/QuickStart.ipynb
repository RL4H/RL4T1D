# %%
# %env MAIN_PATH=$/home/chirath/Documents/G2P2C/RL4T1D

MAIN_PATH='home/chirath/Documents/G2P2C/RL4T1D'

# import os
# os.environ["MAIN_PATH"] = "/home/chirath/Documents/G2P2C/RL4T1D"

import os
import sys
sys.path.insert(1, MAIN_PATH)

from hydra import initialize, initialize_config_module, initialize_config_dir, compose
from omegaconf import OmegaConf

initialize(version_base=None, config_path="../configs", job_name="tery")
cfg = compose(config_name="config.yaml", return_hydra_config=True, overrides=["agent.debug=True", "hydra/job_logging=disabled"])
print(cfg)
# Out:
# env: MAIN_PATH=$/home/chirath/Documents/G2P2C/RL4T1D
# ...

# %%
print(cfg.experiment.experiment_dir)

from agents.algorithm.ppo import PPO

from utils.logger import setup_folders
setup_folders(cfg)
agent = PPO(args=cfg.agent, env_args=cfg.env, load_model=False, actor_path='', critic_path='')
# Out:
# ---------------------------------------------------------------------------
# InterpolationResolutionError              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(cfg.experiment.experiment_dir)
#       3 from agents.algorithm.ppo import PPO
#       5 from utils.logger import setup_folders
#
# File ~/Documents/G2P2C/lib/python3.10/site-packages/omegaconf/dictconfig.py:359, in DictConfig.__getattr__(self, key)
#     355     self._format_and_raise(
#     356         key=key, value=None, cause=e, type_override=ConfigAttributeError
#     357     )
#     358 except Exception as e:
# --> 359     self._format_and_raise(key=key, value=None, cause=e)
#
# File ~/Documents/G2P2C/lib/python3.10/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# ...
